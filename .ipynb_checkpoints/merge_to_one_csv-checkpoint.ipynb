# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
prefix = 'without'
current = pd.read_csv(prefix + '_cur.csv')
desired = pd.read_csv(prefix + '_des.csv')
current.columns = ['timestamp', 'rel_pos_current']
desired.columns = ['timestamp', 'rel_pos_desired']
current['timestamp'] = current['timestamp'].astype(str).str[:-7].astype(np.int64)
desired['timestamp'] = desired['timestamp'].astype(str).str[:-7].astype(np.int64)

count = 0
start = current['timestamp'][0]
for timestamp in current['timestamp']:
    current['timestamp'][count] = current['timestamp'][count] - start
    count += 1
count = 0
start = current['timestamp'][0]
for timestamp in current['timestamp']:
    current['timestamp'][count] = current['timestamp'][count] - start
    count += 1
# Out:
# C:\Users\felix\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#      timestamp  rel_pos_current
# 0            0         0.049012
# 1            5         0.048534
# 2           10         0.047645
# 3           15         0.045622
# 4           20         0.043866
# 5           25         0.040700
# 6           30         0.038302
# 7           35         0.035722
# 8           41         0.033027
# 9           46         0.028764
# 10          51         0.025769
# 11          56         0.022724
# 12          61         0.019714
# 13          66         0.015293
# 14          71         0.012368
# 15          76         0.008195
# 16          81         0.005643
# 17          86         0.003267
# 18          91         0.000006
# 19          96        -0.002023
# 20         101        -0.003924
# 21         106        -0.006392
# 22         111        -0.007690
# 23         117        -0.008702
# 24         121        -0.009475
# 25         126        -0.010335
# 26         131        -0.010737
# 27         137        -0.011019
# 28         142        -0.011212
# 29         147        -0.011208
# ..         ...              ...
# 324       1647        -1.085760
# 325       1653        -1.076060
# 326       1658        -1.062740
# 327       1663        -1.054840
# 328       1668        -1.044770
# 329       1673        -1.039830
# 330       1678        -1.035970
# 331       1683        -1.032020
# 332       1688        -1.028500
# 333       1693        -1.028040
# 334       1698        -1.028130
# 335       1703        -1.029030
# 336       1708        -1.030240
# 337       1713        -1.031520
# 338       1719        -1.032970
# 339       1724        -1.033520
# 340       1729        -1.033740
# 341       1734        -1.033400
# 342       1739        -1.032750
# 343       1744        -1.031740
# 344       1749        -1.029580
# 345       1755        -1.027680
# 346       1760        -1.025420
# 347       1765        -1.021310
# 348       1770        -1.018090
# 349       1775        -1.014490
# 350       1780        -1.008440
# 351       1785        -1.003950
# 352       1790        -0.999059
# 353       1795        -0.993821
#
# [354 rows x 2 columns]

# %%
df = current.merge(desired, on='timestamp')
df.plot(kind='line', y=['rel_pos_current', 'rel_pos_desired'],x='timestamp')
current
# Out:
# C:\Users\felix\Anaconda3\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
#         timestamp  rel_pos_current
# 0    154445196359         0.049012
# 1    154445196364         0.048534
# 2    154445196369         0.047645
# 3    154445196374         0.045622
# 4    154445196379         0.043866
# 5    154445196384         0.040700
# 6    154445196389         0.038302
# 7    154445196394         0.035722
# 8    154445196400         0.033027
# 9    154445196405         0.028764
# 10   154445196410         0.025769
# 11   154445196415         0.022724
# 12   154445196420         0.019714
# 13   154445196425         0.015293
# 14   154445196430         0.012368
# 15   154445196435         0.008195
# 16   154445196440         0.005643
# 17   154445196445         0.003267
# 18   154445196450         0.000006
# 19   154445196455        -0.002023
# 20   154445196460        -0.003924
# 21   154445196465        -0.006392
# 22   154445196470        -0.007690
# 23   154445196476        -0.008702
# 24   154445196480        -0.009475
# 25   154445196485        -0.010335
# 26   154445196490        -0.010737
# 27   154445196496        -0.011019
# 28   154445196501        -0.011212
# 29   154445196506        -0.011208
# ..            ...              ...
# 324  154445198006        -1.085760
# 325  154445198012        -1.076060
# 326  154445198017        -1.062740
# 327  154445198022        -1.054840
# 328  154445198027        -1.044770
# 329  154445198032        -1.039830
# 330  154445198037        -1.035970
# 331  154445198042        -1.032020
# 332  154445198047        -1.028500
# 333  154445198052        -1.028040
# 334  154445198057        -1.028130
# 335  154445198062        -1.029030
# 336  154445198067        -1.030240
# 337  154445198072        -1.031520
# 338  154445198078        -1.032970
# 339  154445198083        -1.033520
# 340  154445198088        -1.033740
# 341  154445198093        -1.033400
# 342  154445198098        -1.032750
# 343  154445198103        -1.031740
# 344  154445198108        -1.029580
# 345  154445198114        -1.027680
# 346  154445198119        -1.025420
# 347  154445198124        -1.021310
# 348  154445198129        -1.018090
# 349  154445198134        -1.014490
# 350  154445198139        -1.008440
# 351  154445198144        -1.003950
# 352  154445198149        -0.999059
# 353  154445198154        -0.993821
#
# [354 rows x 2 columns]

# %%
df.to_csv(prefix + '.csv')
